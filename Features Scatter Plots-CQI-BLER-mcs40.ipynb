# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
from matplotlib.backends.backend_pdf import PdfPages
from pylab import *
file=np.genfromtxt("C:/Users/kabdullah/Paper/Data_CQI_BLER_mcslarger40.csv", delimiter=',',dtype=float)
data=file[1:,:]

# %%
df = pd.read_csv("C:/Users/kabdullah/Paper/Data_CQI_BLER_mcslarger40.csv")

# %%
df.corr()
# Out:
#                                             (HU) Average CQI Per Cell  \
# (HU) Average CQI Per Cell                                    1.000000
# (HU) Average UE Number                                      -0.242757
# (HU) User DL Average Throughput (Mbps)                       0.236271
# (HU) DL PRB Utilization(%)                                  -0.321919
# (HU) DL Traffic Volume (GBytes)                             -0.281970
# (Voda) PDSCH MCS 17-28 Percentage - RAN(%)                   0.540231
# (Voda) DL IBLER(%)                                          -0.380355
# L.Traffic.ActiveUser.DL.Avg                                 -0.255846
#
#                                             (HU) Average UE Number  \
# (HU) Average CQI Per Cell                                -0.242757
# (HU) Average UE Number                                    1.000000
# (HU) User DL Average Throughput (Mbps)                   -0.162826
# ...

# %%
#Indexing
cqi=data[:,0]
ue=data[:,1]
thpt=data[:,2]
prb=data[:,3]
volume=data[:,4]
mcs=data[:,5]
bler=data[:,6]
au=data[:,7]

# %%
#Fabraka cQI
x=cqi
y=thpt
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()

fig = plt.figure()
ax = fig.add_subplot(111)
hb = ax.hexbin(x, y, gridsize=40, bins='log', cmap='RdBu_r',mincnt=1)
ax.axis([xmin, xmax, ymin, ymax])
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('Channel Quality Indicator (CQI)', fontsize='large')
#cb = fig.colorbar(hb, ax=ax, ticks=[0,1,2,3,4,5,6])
cb = fig.colorbar(hb, ax=ax, ticks=[0,100])
cb.set_label('Sample Count',labelpad=-20)
ax2 = cb.ax
#ax2.text(1.3,0.0,'Foo-0',rotation=0)
ax2.text(1.3,0.133,'$10^1$',rotation=0)
ax2.text(1.3,0.333,'$10^2$',rotation=0)
ax2.text(1.3,0.533,'$10^3$',rotation=0)
ax2.text(1.3,0.733,'$10^4$',rotation=0)
ax2.text(1.3,0.955,'$10^5$',rotation=0)
plt.rcParams["figure.figsize"] = (5,4)
ax.grid(True,linestyle='--',linewidth=1,which='both', alpha=0.3)
savefig('CQI-heatmap-fab-40.pdf', bbox_inches='tight')
plt.show()

# %%
#Fabraka BLER
x=bler
y=thpt
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()

fig = plt.figure()
ax = fig.add_subplot(111)
hb = ax.hexbin(x, y, gridsize=40, bins='log', cmap='RdBu_r',mincnt=1)
ax.axis([xmin, xmax, ymin, ymax])
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('Block Error Rate (%)', fontsize='large')
#cb = fig.colorbar(hb, ax=ax, ticks=[0,1,2,3,4,5,6])
cb = fig.colorbar(hb, ax=ax, ticks=[0,100])
cb.set_label('Sample Count',labelpad=-20)
ax2 = cb.ax
#ax2.text(1.3,0.0,'Foo-0',rotation=0)
ax2.text(1.3,0.133,'$10^1$',rotation=0)
ax2.text(1.3,0.333,'$10^2$',rotation=0)
ax2.text(1.3,0.533,'$10^3$',rotation=0)
ax2.text(1.3,0.733,'$10^4$',rotation=0)
ax2.text(1.3,0.955,'$10^5$',rotation=0)
plt.rcParams["figure.figsize"] = (5,4)
ax.grid(True,linestyle='--',linewidth=1,which='both', alpha=0.3)
savefig('BLER-heatmap-fab-40.pdf', bbox_inches='tight')
plt.show()

# %%
#Fabraka AU
x=au
y=thpt
xmin = x.min()
xmax = 20
ymin = y.min()
ymax = y.max()

fig = plt.figure()
ax = fig.add_subplot(111)
hb = ax.hexbin(x, y, gridsize=40, bins='log', cmap='RdBu_r',mincnt=1)
ax.axis([xmin, xmax, ymin, ymax])
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('Number of Active Users', fontsize='large')
#cb = fig.colorbar(hb, ax=ax, ticks=[0,1,2,3,4,5,6])
cb = fig.colorbar(hb, ax=ax, ticks=[0,100])
cb.set_label('Sample Count',labelpad=-20)
ax2 = cb.ax
#ax2.text(1.3,0.0,'Foo-0',rotation=0)
ax2.text(1.3,0.133,'$10^1$',rotation=0)
ax2.text(1.3,0.333,'$10^2$',rotation=0)
ax2.text(1.3,0.533,'$10^3$',rotation=0)
ax2.text(1.3,0.733,'$10^4$',rotation=0)
ax2.text(1.3,0.955,'$10^5$',rotation=0)
plt.rcParams["figure.figsize"] = (5,4)
ax.grid(True,linestyle='--',linewidth=1,which='both', alpha=0.3)
savefig('AU-heatmap-fab.pdf', bbox_inches='tight')
plt.show()

# %%
#Fabraka PRB
x=prb
y=thpt
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()

fig = plt.figure()
ax = fig.add_subplot(111)
hb = ax.hexbin(x, y, gridsize=40, bins='log', cmap='RdBu_r',mincnt=1)
ax.axis([xmin, xmax, ymin, ymax])
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('PRB Utilization (%)', fontsize='large')
#cb = fig.colorbar(hb, ax=ax, ticks=[0,1,2,3,4,5,6])
cb = fig.colorbar(hb, ax=ax, ticks=[0,100])
cb.set_label('Sample Count',labelpad=-20)
ax2 = cb.ax
#ax2.text(1.3,0.0,'Foo-0',rotation=0)
ax2.text(1.3,0.133,'$10^1$',rotation=0)
ax2.text(1.3,0.333,'$10^2$',rotation=0)
ax2.text(1.3,0.533,'$10^3$',rotation=0)
ax2.text(1.3,0.733,'$10^4$',rotation=0)
ax2.text(1.3,0.955,'$10^5$',rotation=0)
plt.rcParams["figure.figsize"] = (5,4)
ax.grid(True,linestyle='--',linewidth=1,which='both', alpha=0.3)
savefig('PRB-heatmap-fab.pdf', bbox_inches='tight')
plt.show()

# %%
#Fabraka High-Order MCS Penetration (%)
x=mcs
y=thpt
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()

fig = plt.figure()
ax = fig.add_subplot(111)
hb = ax.hexbin(x, y, gridsize=40, bins='log', cmap='RdBu_r',mincnt=1)
ax.axis([xmin, xmax, ymin, ymax])
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('High-Order MCS Penetration (%))', fontsize='large')
#cb = fig.colorbar(hb, ax=ax, ticks=[0,1,2,3,4,5,6])
cb = fig.colorbar(hb, ax=ax, ticks=[0,100])
cb.set_label('Sample Count',labelpad=-20)
ax2 = cb.ax
#ax2.text(1.3,0.0,'Foo-0',rotation=0)
ax2.text(1.3,0.133,'$10^1$',rotation=0)
ax2.text(1.3,0.333,'$10^2$',rotation=0)
ax2.text(1.3,0.533,'$10^3$',rotation=0)
ax2.text(1.3,0.733,'$10^4$',rotation=0)
ax2.text(1.3,0.955,'$10^5$',rotation=0)
plt.rcParams["figure.figsize"] = (5,4)
ax.grid(True,linestyle='--',linewidth=1,which='both', alpha=0.3)
savefig('MCS-heatmap-fab.pdf', bbox_inches='tight')
plt.show()

# %%
#Fabraka RRC Connected Users
x=ue
y=thpt
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()

fig = plt.figure()
ax = fig.add_subplot(111)
hb = ax.hexbin(x, y, gridsize=40, bins='log', cmap='RdBu_r',mincnt=1)
ax.axis([xmin, xmax, ymin, ymax])
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('Number of RRC Connected Users', fontsize='large')
#cb = fig.colorbar(hb, ax=ax, ticks=[0,1,2,3,4,5,6])
cb = fig.colorbar(hb, ax=ax, ticks=[0,100])
cb.set_label('Sample Count',labelpad=-20)
ax2 = cb.ax
#ax2.text(1.3,0.0,'Foo-0',rotation=0)
ax2.text(1.3,0.133,'$10^1$',rotation=0)
ax2.text(1.3,0.333,'$10^2$',rotation=0)
ax2.text(1.3,0.533,'$10^3$',rotation=0)
ax2.text(1.3,0.733,'$10^4$',rotation=0)
ax2.text(1.3,0.955,'$10^5$',rotation=0)
plt.rcParams["figure.figsize"] = (5,4)
ax.grid(True,linestyle='--',linewidth=1,which='both', alpha=0.3)
savefig('RRC-heatmap-fab.pdf', bbox_inches='tight')
plt.show()

# %%
#Fabraka Data Volume
x=volume
y=thpt
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()

fig = plt.figure()
ax = fig.add_subplot(111)
hb = ax.hexbin(x, y, gridsize=40, bins='log', cmap='RdBu_r',mincnt=1)
ax.axis([xmin, xmax, ymin, ymax])
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('Data Volume (GBytes)', fontsize='large')
#cb = fig.colorbar(hb, ax=ax, ticks=[0,1,2,3,4,5,6])
cb = fig.colorbar(hb, ax=ax, ticks=[0,100])
cb.set_label('Sample Count',labelpad=-20)
ax2 = cb.ax
#ax2.text(1.3,0.0,'Foo-0',rotation=0)
ax2.text(1.3,0.133,'$10^1$',rotation=0)
ax2.text(1.3,0.333,'$10^2$',rotation=0)
ax2.text(1.3,0.533,'$10^3$',rotation=0)
ax2.text(1.3,0.733,'$10^4$',rotation=0)
ax2.text(1.3,0.955,'$10^5$',rotation=0)
plt.rcParams["figure.figsize"] = (5,4)
ax.grid(True,linestyle='--',linewidth=1,which='both', alpha=0.3)
savefig('Vol-heatmap-fab.pdf', bbox_inches='tight')
plt.show()

# %%
#Orginal
x=au
y=thpt
xmin = x.min()
xmax = 20
ymin = y.min()
ymax = y.max()
fig = plt.figure()
ax = fig.add_subplot(111)
bounds=[0,6]
hb = ax.hexbin(x, y, gridsize=40,cmap='RdBu_r',bins='log',mincnt=1) #RdBu_r
ax.axis([xmin, xmax, ymin, ymax])
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('Number of Active Users', fontsize='large')
cb = fig.colorbar(hb, ax=ax)
cb.set_label('Sample Count(Log. Scale)')
plt.rcParams["figure.figsize"] = (5,4)
ax.grid(True,linestyle='--',linewidth=1,which='both', alpha=0.3)
savefig('AU-heatmap-log.pdf', bbox_inches='tight')
plt.show()

# %%
x1=prb
x=au
y=thpt
xmin = x.min()
xmax = 20
xmin1 = x1.min()
xmax1 = x1.max()
ymin = y.min()
ymax = y.max()

fig, axs = plt.subplots(ncols=2, sharey=True, figsize=(7, 4))
fig.subplots_adjust(hspace=0.5, left=0.07, right=0.93)
ax = axs[0]
hb = ax.hexbin(x, y, gridsize=50, bins='log', cmap='Greys')
ax.axis([xmin, xmax, ymin, ymax])
ax.set_title("User Throughput Vs Active Users")
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('# of Active Users', fontsize='large')
cb = fig.colorbar(hb, ax=ax)
cb.set_label('Density-log10(N)')

ax = axs[1]
hb = ax.hexbin(x1, y, gridsize=50, bins='log', cmap='Greys')
ax.axis([xmin1, xmax1, ymin, ymax])
ax.set_title(" Vs PRB Utilization")
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('PRB Utilization (%)', fontsize='large')
cb = fig.colorbar(hb, ax=ax)
cb.set_label('Density-log10(N)')
savefig('AU-PRB.pdf', bbox_inches='tight')
plt.show()

# %%
x1=ue
x=mcs
y=thpt
xmin = x.min()
xmax = x.max()
xmin1 = x1.min()
xmax1 = x1.max()
ymin = y.min()
ymax = y.max()

fig, axs = plt.subplots(ncols=2, sharey=True, figsize=(10, 4))
fig.subplots_adjust(hspace=0.5, left=0.07, right=0.93)
ax = axs[0]
hb = ax.hexbin(x, y, gridsize=50,cmap='Greys',mincnt=1,bins='log')
ax.axis([xmin, xmax, ymin, ymax])
ax.set_title("Vs High-Order MCS Penetration")
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('High-Order MCS Penetration (%)', fontsize='large')
cb = fig.colorbar(hb, ax=ax)
cb.set_label('Density-log10(N)')

ax = axs[1]
hb = ax.hexbin(x1, y, gridsize=50, bins='log', cmap='Greys',mincnt=1)
ax.axis([xmin1, xmax1, ymin, ymax])
ax.set_title("Vs RRC Connected Users")
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('# of RRC Connected Users', fontsize='large')
cb = fig.colorbar(hb, ax=ax)
cb.set_label('Density-log10(N)')
savefig('MCS-UE1.pdf', bbox_inches='tight')
plt.show()

# %%
x=au
y=thpt
xmin = x.min()
xmax = 20
ymin = y.min()
ymax = y.max()

fig = plt.figure()
ax = fig.add_subplot(111)
#2nd Axis
hb = ax.hexbin(x, y, gridsize=40, bins='log', cmap='RdBu_r',mincnt=1) #RdBu_r
ax.axis([xmin, xmax, ymin, ymax])
ax.set_ylabel('Average User Throughput (Mbps)', fontsize='large')
ax.set_xlabel('Number of Active Users', fontsize='large')
#bounds=[0,4]
#cb = fig.colorbar(hb, ax=ax,boundaries=bounds)
cb = fig.colorbar(hb, ax=ax,ticks=[0,100])
#cb = fig.colorbar(hb, ax=ax)
#cb.set_label('Sample Count (Log. Scale)')
cb.set_label('10      100        1000        10000        100000\n  \n\nSample Count',labelpad=-20)
#ax2 = cb.ax
#ax2.text(1.3,0.5,'Foo', 'Hello',rotation=0)
plt.rcParams["figure.figsize"] = (5,4)
ax.grid(True,linestyle='--',linewidth=1,which='both', alpha=0.3)
savefig('AU-heatmap-fab.pdf', bbox_inches='tight')
plt.show()

# %%
#Features Selection 2: Correlations
corr = df.corr()
# Set up the matplotlib figure
#f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=1, center=0,
             linewidths=.5)

# %%
x=au
y=thpt
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()

fig, axs = plt.subplots(ncols=2, sharey=True, figsize=(7, 4))
fig.subplots_adjust(hspace=0.5, left=0.07, right=0.93)
ax = axs[0]
hb = ax.hexbin(x, y, gridsize=50, cmap='Greys')
ax.axis([xmin, xmax, ymin, ymax])
ax.set_title("Hexagon binning")
cb = fig.colorbar(hb, ax=ax)
cb.set_label('counts')

ax = axs[1]
hb = ax.hexbin(x, y, gridsize=50, bins='log', cmap='Greys')
ax.axis([xmin, xmax, ymin, ymax])
ax.set_title("With a log color scale")
cb = fig.colorbar(hb, ax=ax)
cb.set_label('log10(N)')

plt.show()

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.jointplot(au, thpt);

# %%
plt.hist2d(au, thpt, bins=(100, 100), cmap=plt.cm.Reds)
plt.xlim((0,2))
plt.ylim((0,100))
plt.colorbar()
plt.show()

# %%
plt.hist2d(au, thpt, bins=(100, 100), cmap='inferno')
plt.xlim((0,2))
plt.ylim((0,100))
plt.colorbar()
plt.show()

# %%
plt.scatter(au,thpt,cmap='jet')
plt.show()

# %%
#histogram definition
import scipy
xyrange = [[0,40],[0,90]] # data range
bins = [100,100] # number of bins
thresh = 3  #density threshold
xdat=au
ydat=thpt
# histogram the data
hh, locx, locy = scipy.histogram2d(xdat, ydat, range=xyrange, bins=bins)
posx = np.digitize(xdat, locx)
posy = np.digitize(ydat, locy)

#select points within the histogram
ind = (posx > 0) & (posx <= bins[0]) & (posy > 0) & (posy <= bins[1])
hhsub = hh[posx[ind] - 1, posy[ind] - 1] # values of the histogram where the points are
xdat1 = xdat[ind][hhsub < thresh] # low density points
ydat1 = ydat[ind][hhsub < thresh]
hh[hh < thresh] = np.nan # fill the areas with low density by NaNs

plt.imshow(np.flipud(hh.T),cmap='jet',extent=np.array(xyrange).flatten(), interpolation='none', origin='upper')
plt.colorbar()   
plt.plot(xdat1, ydat1, '.',color='darkblue')
savefig('trial.pdf', bbox_inches='tight')
plt.show()

# %%
with sns.axes_style("white"):
    k=sns.jointplot(au,thpt, kind="hex", color="k");
